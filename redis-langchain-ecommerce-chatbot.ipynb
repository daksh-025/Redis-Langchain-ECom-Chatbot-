# %% [markdown]
# # Redis LangChain OpenAI eCommerce Chatbot

# %%
# Install requirements
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: redis==4.5.3 in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 2)) (4.5.3)
# Requirement already satisfied: numpy in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 4)) (1.24.4)
# Requirement already satisfied: pandas in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: gdown in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from -r requirements.txt (line 6)) (4.7.1)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from redis==4.5.3->-r requirements.txt (line 2)) (4.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\daksh\appdata\roaming\python\python39\site-packages (from pandas->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from pandas->-r requirements.txt (line 5)) (2022.7.1)
# Requirement already satisfied: requests[socks] in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from gdown->-r requirements.txt (line 6)) (2.31.0)
# Requirement already satisfied: six in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from gdown->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from gdown->-r requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: filelock in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from gdown->-r requirements.txt (line 6)) (3.12.2)
# Requirement already satisfied: tqdm in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from gdown->-r requirements.txt (line 6)) (4.65.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from beautifulsoup4->gdown->-r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]->gdown->-r requirements.txt (line 6)) (2023.5.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]->gdown->-r requirements.txt (line 6)) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]->gdown->-r requirements.txt (line 6)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]->gdown->-r requirements.txt (line 6)) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]->gdown->-r requirements.txt (line 6)) (1.7.1)
# Requirement already satisfied: colorama in c:\users\daksh\appdata\local\programs\python\python39\lib\site-packages (from tqdm->gdown->-r requirements.txt (line 6)) (0.4.6)
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the 'C:\Users\daksh\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
# Download the dataset
# !gdown --id 1tHWB6u3yQCuAgOYc-DxtZ8Mru3uV5_lj
# Out:
# C:\Users\daksh\AppData\Local\Programs\Python\Python39\lib\site-packages\gdown\cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1tHWB6u3yQCuAgOYc-DxtZ8Mru3uV5_lj
# From (redirected): https://drive.google.com/uc?id=1tHWB6u3yQCuAgOYc-DxtZ8Mru3uV5_lj&confirm=t&uuid=2916ed56-a66e-4c17-9a28-3906367b2486
# To: c:\Users\daksh\Downloads\redis-langchain-chatbot-main\redis-langchain-chatbot-main\product_data.csv
#
#   0%|          | 0.00/225M [00:00<?, ?B/s]
#   0%|          | 524k/225M [00:00<02:29, 1.50MB/s]
#   1%|          | 1.57M/225M [00:00<00:57, 3.91MB/s]
#   2%|▏         | 4.19M/225M [00:00<00:22, 9.60MB/s]
#   3%|▎         | 5.77M/225M [00:00<00:21, 10.2MB/s]
#   4%|▍         | 8.91M/225M [00:00<00:15, 14.3MB/s]
#   5%|▍         | 11.0M/225M [00:01<00:14, 14.3MB/s]
#   6%|▌         | 12.6M/225M [00:01<00:15, 14.0MB/s]
#   7%|▋         | 14.7M/225M [00:01<00:13, 15.7MB/s]
#   7%|▋         | 16.8M/225M [00:01<00:13, 15.7MB/s]
#   8%|▊         | 18.9M/225M [00:01<00:14, 14.4MB/s]
#  10%|▉         | 21.5M/225M [00:01<00:12, 15.7MB/s]
#  11%|█         | 23.6M/225M [00:01<00:13, 15.3MB/s]
#  11%|█▏        | 25.7M/225M [00:01<00:13, 15.1MB/s]
#  79%|███████▉  | 178M/225M [00:13<00:03, 14.9MB/s]
#  80%|████████  | 180M/225M [00:14<00:03, 14.1MB/s]
#  81%|████████  | 181M/225M [00:14<00:03, 13.4MB/s]
#  81%|████████▏ | 183M/225M [00:14<00:03, 12.8MB/s]
#  82%|████████▏ | 185M/225M [00:14<00:03, 12.5MB/s]
#  83%|████████▎ | 186M/225M [00:14<00:03, 12.3MB/s]
#  84%|████████▎ | 188M/225M [00:14<00:03, 12.0MB/s]
#  84%|████████▍ | 189M/225M [00:14<00:02, 12.0MB/s]
#  85%|████████▍ | 191M/225M [00:15<00:02, 12.0MB/s]
#  86%|████████▌ | 192M/225M [00:15<00:02, 11.8MB/s]
#  86%|████████▋ | 194M/225M [00:15<00:02, 11.8MB/s]
#  87%|████████▋ | 196M/225M [00:15<00:02, 11.7MB/s]
#  88%|████████▊ | 197M/225M [00:15<00:02, 11.7MB/s]
#  88%|████████▊ | 199M/225M [00:15<00:02, 11.6MB/s]
#  89%|████████▉ | 200M/225M [00:15<00:02, 11.7MB/s]
#  90%|████████▉ | 202M/225M [00:16<00:01, 11.6MB/s]
#  91%|█████████ | 203M/225M [00:16<00:01, 11.8MB/s]
#  91%|█████████▏| 205M/225M [00:16<00:01, 11.6MB/s]
#  92%|█████████▏| 207M/225M [00:16<00:01, 11.7MB/s]
#  93%|█████████▎| 208M/225M [00:16<00:01, 11.7MB/s]
#  94%|█████████▍| 211M/225M [00:16<00:00, 14.4MB/s]
#  95%|█████████▍| 213M/225M [00:16<00:00, 14.6MB/s]
#  96%|█████████▌| 215M/225M [00:16<00:00, 14.8MB/s]
#  96%|█████████▋| 217M/225M [00:17<00:00, 14.8MB/s]
#  97%|█████████▋| 218M/225M [00:17<00:00, 14.1MB/s]
#  99%|█████████▊| 221M/225M [00:17<00:00, 17.5MB/s]
#  99%|█████████▉| 223M/225M [00:17<00:00, 16.4MB/s]
# 100%|██████████| 225M/225M [00:17<00:00, 12.8MB/s]

# %% [markdown]
# ## Preprocess dataset

# %%
import pandas as pd

MAX_TEXT_LENGTH=512

def auto_truncate(val):
    """Truncate the given text."""
    return val[:MAX_TEXT_LENGTH]

# Load Product data and truncate long text fields
all_prods_df = pd.read_csv("product_data.csv", converters={
    'bullet_point': auto_truncate,
    'item_keywords': auto_truncate,
    'item_name': auto_truncate
})

# %%
# Contruct a primary key from item ID and domain name
all_prods_df['primary_key'] = (
    all_prods_df['item_id'] + '-' + all_prods_df['domain_name']
)
# Replace empty strings with None and drop
all_prods_df['item_keywords'].replace('', None, inplace=True)
all_prods_df.dropna(subset=['item_keywords'], inplace=True)

# Reset pandas dataframe index
all_prods_df.reset_index(drop=True, inplace=True)

all_prods_df.head()
# Out:
#       item_id marketplace country main_image_id domain_name  \
# 0  B07T6RZ2CM      Amazon      IN   71dZhpsferL   amazon.in
# 1  B07T2JY31Y      Amazon      IN   71vX7qIEAIL   amazon.in
# 2  B0849YGSCZ      Amazon      AE   A1EZF-2mB5L   amazon.ae
# 3  B081K6TCML      Amazon      IN   81o9EyZ-fAL   amazon.in
# 4  B0854774X5      Amazon      IN   81xaJCVnl3L   amazon.in
#
#                                         bullet_point  \
# 0  3D Printed Hard Back Case Mobile Cover for Len...
# 1  3D Printed Hard Back Case Mobile Cover for Son...
# 2
# 3  Solimo Plastic Multipurpose Modular Drawer; sm...
# 4  Snug fit for Nokia 8.1, with perfect cut-outs ...
#
#                                        item_keywords material  \
# 0  mobile cover back cover mobile case phone case...      NaN
# 1  mobile cover back cover mobile case phone case...     Wood
# 2  small de fur rooms navidad woven girls shag pa...      NaN
# 3  drawer modular drawer 3 rack modular drawer ki...  Plastic
# 4  Back Cover Designer Case Designer Take It Easy...  Silicon
#
#                    brand       color  \
# 0  Amazon Brand - Solimo      Others
# 1  Amazon Brand - Solimo      others
# 2           Stone & Beam         NaN
# 3  Amazon Brand - Solimo  Multicolor
# 4  Amazon Brand - Solimo  Multicolor
#
#                                            item_name           model_name  \
# 0  Amazon Brand - Solimo Designer Couples Sitting...       Lenovo K4 Note
# 1  Amazon Brand - Solimo Designer Leaf on Wood 3D...  Sony Xperia Z1 L39H
# 2  Stone & Beam Contemporary Doily Wool Farmhouse...                  NaN
# 3  Amazon Brand - Solimo Plastic Multipurpose Mod...                  NaN
# 4  Amazon Brand - Solimo Designer Take It Easy UV...            Nokia 8.1
#
#                model_number              product_type           primary_key
# 0            gz8115-SL40423       CELLULAR_PHONE_CASE  B07T6RZ2CM-amazon.in
# 1            gz8056-SL40528       CELLULAR_PHONE_CASE  B07T2JY31Y-amazon.in
# 2  I59I8044IVYGRYC00-Parent  HOME_FURNITURE_AND_DECOR  B0849YGSCZ-amazon.ae
# 3               sol_cujo_13                      HOME  B081K6TCML-amazon.in
# 4           UV10714-SL40617       CELLULAR_PHONE_CASE  B0854774X5-amazon.in

# %%
# Num products to use (subset)
NUMBER_PRODUCTS = 2500  

# Get the first 1000 products with non-empty item keywords
product_metadata = ( 
    all_prods_df
     .head(NUMBER_PRODUCTS)
     .to_dict(orient='index')
)

# %%
# Check one of the products
product_metadata[0]
# Out:
# {'item_id': 'B07T6RZ2CM',
#  'marketplace': 'Amazon',
#  'country': 'IN',
#  'main_image_id': '71dZhpsferL',
#  'domain_name': 'amazon.in',
#  'bullet_point': '3D Printed Hard Back Case Mobile Cover for Lenovo K4 Note Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports. Stylish design and appearance, express your unique personality. Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface. Slim Hard Back Cover No Warranty None',
#  'item_keywords': 'mobile cover back cover mobile case phone case mobile panel phone panel Lenovo mobile case Lenovo phone cover Lenovo back case hard case 3D printed mobile cover mobile cover back cover mobile case phone case mobile panel phone panel Lenovo mobile case Lenovo phone cover Lenovo back case hard case 3D printed mobile cover mobile cover back cover mobile case phone case mobile panel phone panel Lenovo mobile case Lenovo phone cover Lenovo back case hard case 3D printed mobile cover mobile cover back cover mobil',
#  'material': nan,
#  'brand': 'Amazon Brand - Solimo',
#  'color': 'Others',
#  'item_name': 'Amazon Brand - Solimo Designer Couples Sitting at Dark 3D Printed Hard Back Case Mobile Cover for Lenovo K4 Note',
#  'model_name': 'Lenovo K4 Note',
#  'model_number': 'gz8115-SL40423',
#  'product_type': 'CELLULAR_PHONE_CASE',
#  'primary_key': 'B07T6RZ2CM-amazon.in'}

# %% [markdown]
# ## Set up Redis as a vector db

# %%
from langchain.embeddings import OpenAIEmbeddings
import os
from langchain.vectorstores.redis import Redis as RedisVectorStore
os.environ['OPENAI_API_KEY'] = "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"

# data that will be embedded and converted to vectors
texts = [
    v['item_name'] for k, v in product_metadata.items()
]

# product metadata that we'll store along our vectors
metadatas = list(product_metadata.values())

# we will use OpenAI as our embeddings provider
embedding = OpenAIEmbeddings()

# name of the Redis search index to create
index_name = "products"

# assumes you have a redis stack server running on within your docker compose network
redis_url = "redis://redis:6379"

# create and load redis with documents
vectorstore = RedisVectorStore.from_texts(
    texts=texts,
    metadatas=metadatas,
    embedding=embedding,
    index_name=index_name,
    redis_url=redis_url
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# c:\Users\daksh\Downloads\redis-langchain-chatbot-main\redis-langchain-chatbot-main\redis-langchain-ecommerce-chatbot.ipynb Cell 10 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/daksh/Downloads/redis-langchain-chatbot-main/redis-langchain-chatbot-main/redis-langchain-ecommerce-chatbot.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a> metadatas = list(product_metadata.values())
#      <a href='vscode-notebook-cell:/c%3A/Users/daksh/Downloads/redis-langchain-chatbot-main/redis-langchain-chatbot-main/redis-langchain-ecommerce-chatbot.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> # we will use OpenAI as our embeddings provider
# ---> <a href='vscode-notebook-cell:/c%3A/Users/daksh/Downloads/redis-langchain-chatbot-main/redis-langchain-chatbot-main/redis-langchain-ecommerce-chatbot.ipynb#X12sZmlsZQ%3D%3D?line=12'>13</a> embedding = OpenAIEmbeddings()
#      <a href='vscode-notebook-cell:/c%3A/Users/daksh/Downloads/redis-langchain-chatbot-main/redis-langchain-chatbot-main/redis-langchain-ecommerce-chatbot.ipynb#X12sZmlsZQ%3D%3D?line=14'>15</a> # name of the Redis search index to create
#      <a href='vscode-notebook-cell:/c%3A/Users/daksh/Downloads/redis-langchain-chatbot-main/redis-langchain-chatbot-main/redis-langchain-ecommerce-chatbot.ipynb#X12sZmlsZQ%3D%3D?line=15'>16</a> index_name = "products"
#
# File c:\Users\daksh\AppData\Local\Programs\Python\Python39\lib\site-packages\pydantic\main.py:341, in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for OpenAIEmbeddings
# __root__
#   Did not find openai_api_key, please add an environment variable `OPENAI_API_KEY` which contains it, or pass  `openai_api_key` as a named parameter. (type=value_error)

# %% [markdown]
# ## Build the ChatBot with ConversationalRetrieverChain

# %%
from langchain.callbacks.base import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain.chains import (
    ConversationalRetrievalChain,
    LLMChain
)
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI
from langchain.prompts.prompt import PromptTemplate

template = """Given the following chat history and a follow up question, rephrase the follow up input question to be a standalone question.
Or end the conversation if it seems like it's done.

Chat History:\"""
{chat_history}
\"""

Follow Up Input: \"""
{question}
\"""

Standalone question:"""

condense_question_prompt = PromptTemplate.from_template(template)

template = """You are a friendly, conversational retail shopping assistant. Use the following context including product names, descriptions, and keywords to show the shopper whats available, help find what they want, and answer any questions.
It's ok if you don't know the answer.

Context:\"""
{context}
\"""

Question:\"
\"""

Helpful Answer:"""

qa_prompt= PromptTemplate.from_template(template)


# define two LLM models from OpenAI
llm = OpenAI(temperature=0)

streaming_llm = OpenAI(
    streaming=True,
    callback_manager=CallbackManager([
        StreamingStdOutCallbackHandler()]),
    verbose=True,
    temperature=0.2,
    max_tokens=150
)

# use the LLM Chain to create a question creation chain
question_generator = LLMChain(
    llm=llm,
    prompt=condense_question_prompt
)

# use the streaming LLM to create a question answering chain
doc_chain = load_qa_chain(
    llm=streaming_llm,
    chain_type="stuff",
    prompt=qa_prompt
)


chatbot = ConversationalRetrievalChain(
    retriever=vectorstore.as_retriever(),
    combine_docs_chain=doc_chain,
    question_generator=question_generator
)

# %%
# create a chat history buffer
chat_history = []

# gather user input for the first question to kick off the bot
question = input("Hi! What are you looking for today?")

# keep the bot running in a loop to simulate a conversation
while True:
    result = chatbot(
        {"question": question, "chat_history": chat_history}
    )
    print("\n")
    chat_history.append((result["question"], result["answer"]))
    question = input()

# %% [markdown]
# ## Customize your chains for even better performance

# %%
import json

from langchain.schema import BaseRetriever
from langchain.vectorstores import VectorStore
from langchain.schema import Document
from pydantic import BaseModel


class RedisProductRetriever(BaseRetriever, BaseModel):
    vectorstore: VectorStore

    class Config:
        
        arbitrary_types_allowed = True

    def combine_metadata(self, doc) -> str:
        metadata = doc.metadata
        return (
            "Item Name: " + metadata["item_name"] + ". " +
            "Item Description: " + metadata["bullet_point"] + ". " +
            "Item Keywords: " + metadata["item_keywords"] + "."
        )

    def get_relevant_documents(self, query):
        docs = []
        for doc in self.vectorstore.similarity_search(query):
            content = self.combine_metadata(doc)
            docs.append(Document(
                page_content=content,
                metadata=doc.metadata
            ))
        return docs

# %% [markdown]
# ### Setup ChatBot with new retriever

# %%
redis_product_retriever = RedisProductRetriever(vectorstore=vectorstore)

chatbot = ConversationalRetrievalChain(
    retriever=redis_product_retriever,
    combine_docs_chain=doc_chain,
    question_generator=question_generator
)

# %% [markdown]
# ### Retry

# %%
# create a chat history buffer
chat_history = []

# gather user input for the first question to kick off the bot
question = input("Hi! What are you looking for today?")

# keep the bot running in a loop to simulate a conversation
while True:
    result = chatbot(
        {"question": question, "chat_history": chat_history}
    )
    print("\n")
    chat_history.append((result["question"], result["answer"]))
    question = input()
